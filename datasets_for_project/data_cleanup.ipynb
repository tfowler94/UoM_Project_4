# %%
# Import Dependencies
import pandas as pd
import numpy as np

# %%
# Load CSV files into new DataFrame
hc_expend_vs_gdp = "C:/Users/Tyler/Desktop/UoM_Project_4/kaggle_datasets/healthcare-expenditure-vs-gdp.csv"
hc_protection_cov = "C:/Users/Tyler/Desktop/UoM_Project_4/kaggle_datasets/health-protection-coverage.csv"
child_mortality_vs_health_expenditure = "C:/Users/Tyler/Desktop/UoM_Project_4/kaggle_datasets/child-mortality-vs-health-expenditure.csv"
total_hc_expend_gdp = "C:/Users/Tyler/Desktop/UoM_Project_4/kaggle_datasets/total-healthcare-expenditure-gdp.csv"

# Read CSV file and store in Pandas DataFrame
hc_expend_vs_gdp_df = pd.read_csv(hc_expend_vs_gdp)
hc_protection_cov_df = pd.read_csv(hc_protection_cov)
child_mortality_vs_health_expenditure_df = pd.read_csv(child_mortality_vs_health_expenditure)
total_hc_expend_gdp_df = pd.read_csv(total_hc_expend_gdp)

# %%
hc_expend_vs_gdp_df2 = hc_expend_vs_gdp_df.drop(columns="Continent")
hc_expend_vs_gdp_df3 = hc_expend_vs_gdp_df2.dropna(how="any")

#cleaned dataframe
hc_expend_vs_gdp_df3
# Out:
#             Entity Code  Year  \
# 1      Afghanistan  AFG  2002
# 2      Afghanistan  AFG  2003
# 3      Afghanistan  AFG  2004
# 4      Afghanistan  AFG  2005
# 5      Afghanistan  AFG  2006
# ...            ...  ...   ...
# 55865     Zimbabwe  ZWE  2015
# 55866     Zimbabwe  ZWE  2016
# 55867     Zimbabwe  ZWE  2017
# 55868     Zimbabwe  ZWE  2018
# 55869     Zimbabwe  ZWE  2019
#
#        Current health expenditure per capita, PPP (current international $)  \
# 1                                              81.271034
# 2                                              82.457848
# 3                                              89.470055
# 4                                             100.706985
# 5                                             113.754105
# ...                                                  ...
# 55865                                         199.677658
# 55866                                         215.404556
# ...

# %%
hc_protection_cov_df.head()
# Out:
#                 Entity Code  Year  \
# 0              Albania  ALB  2008
# 1              Algeria  DZA  2005
# 2       American Samoa  ASM  2009
# 3               Angola  AGO  2010
# 4  Antigua and Barbuda  ATG  2007
#
#    Share of population covered by health insurance (ILO (2014))
# 0                                               23.6
# 1                                               85.2
# 2                                                3.0
# 3                                                0.0
# 4                                               51.1

# %%
hc_protection_cov_df2 = hc_protection_cov_df.drop(columns="Year")

#cleaned dataframe
hc_protection_cov_df2
# Out:
#                   Entity Code  \
# 0                Albania  ALB
# 1                Algeria  DZA
# 2         American Samoa  ASM
# 3                 Angola  AGO
# 4    Antigua and Barbuda  ATG
# ..                   ...  ...
# 157            Venezuela  VEN
# 158              Vietnam  VNM
# 159                Yemen  YEM
# 160               Zambia  ZMB
# 161             Zimbabwe  ZWE
#
#      Share of population covered by health insurance (ILO (2014))
# 0                                                 23.6
# 1                                                 85.2
# 2                                                  3.0
# 3                                                  0.0
# 4                                                 51.1
# ..                                                 ...
# 157                                              100.0
# 158                                               61.0
# 159                                               42.0
# ...

# %%
child_mortality_vs_health_expenditure_df.head()
# Out:
#         Entity      Code  Year  \
# 0     Abkhazia  OWID_ABK  2015
# 1  Afghanistan       AFG  1960
# 2  Afghanistan       AFG  1961
# 3  Afghanistan       AFG  1962
# 4  Afghanistan       AFG  1963
#
#    Mortality rate, under-5 (per 1,000 live births)  \
# 0                                              NaN
# 1                                        35.820001
# 2                                        35.220001
# 3                                        34.629999
# 4                                        34.060001
#
#    Current health expenditure per capita, PPP (current international $)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Population (historical estimates) Continent
# 0                                NaN      Asia
# ...

# %%
child_mortality_vs_health_expenditure_df2 = child_mortality_vs_health_expenditure_df.drop(columns="Continent")
child_mortality_vs_health_expenditure_df3 = child_mortality_vs_health_expenditure_df2.dropna(how="any")

#cleaned dataframe
child_mortality_vs_health_expenditure_df3.count()
# Out:
# Entity                                                                  3754
# Code                                                                    3754
# Year                                                                    3754
# Mortality rate, under-5 (per 1,000 live births)                         3754
# Current health expenditure per capita, PPP (current international $)    3754
# Population (historical estimates)                                       3754
# dtype: int64

# %%
total_hc_expend_gdp_df.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  2002
# 1  Afghanistan  AFG  2003
# 2  Afghanistan  AFG  2004
# 3  Afghanistan  AFG  2005
# 4  Afghanistan  AFG  2006
#
#    Indicator:Current health expenditure (CHE) as percentage of gross domestic product (GDP) (%)
# 0                                               9.44
# 1                                               8.94
# 2                                               9.81
# 3                                               9.95
# 4                                              10.62

# %%
#cleaned dataframe
total_hc_expend_gdp_df.count()
# Out:
# Entity                                                                                          3974
# Code                                                                                            3774
# Year                                                                                            3974
# Indicator:Current health expenditure (CHE) as percentage of gross domestic product (GDP) (%)    3974
# dtype: int64

# %%
hc_expend_vs_gdp_df3.to_csv("hc_expend_vs_gdp_df.csv",encoding="utf-8")
hc_protection_cov_df2.to_csv("hc_protection_cov_df.csv",encoding="utf-8")
child_mortality_vs_health_expenditure_df3.to_csv("child_mortality_vs_health_expenditure_df.csv",encoding="utf-8")
total_hc_expend_gdp_df.to_csv("total_hc_expend_gdp_df.csv",encoding="utf-8")
